# %% [markdown]
# 11437번 LCA <span style="color:green">성공</span> - 2025.12.03

# %%
# 두 노드의 깊이를 동일하게 맞춘 뒤, 부모를 타고 올라가며 같은 노드를 만날때까지 반복
import sys
from collections import deque
# input = sys.stdin.readline

def bfs():
    q = deque()

    q.append(1)
    visited[1] = 1
    depth[1] = 0
    while q:
        curr = q.popleft()

        for next in graph[curr]:
            if not visited[next]:
                visited[next] = 1
                parent[next] = curr
                depth[next] = depth[curr] + 1
                q.append(next)

n = int(input())
graph = [[] for _ in range(n + 1)]
for _ in range(n - 1):
    a, b = map(int, input().split())
    graph[a].append(b)
    graph[b].append(a)

visited = [0 for _ in range(n + 1)]
parent = [0 for _ in range(n + 1)]
depth = [0 for _ in range(n + 1)]

bfs()

m = int(input())
for _ in range(m):
    a, b = map(int, input().split())

    if depth[a] != depth[b]:
        while depth[a] != depth[b]:
            if depth[a] < depth[b]:
                b = parent[b]
            
            elif depth[a] > depth[b]:
                a = parent[a]

    while a != b:
        a = parent[a]
        b = parent[b]
    print(a)

# %%
import sys
sys.setrecursionlimit(10**5)
# input = sys.stdin.readline

def dfs(curr, d):
    visited[curr] = 1
    depth[curr] = d

    for next in graph[curr]:
        if not visited[next]:
            parent[next] = curr
            dfs(next, d + 1)

def lca(a, b):
    while depth[a] > depth[b]:
        a = parent[a]
    while depth[b] > depth[a]:
        b = parent[b]
    
    while a != b:
        a = parent[a]
        b = parent[b]
    return a

n = int(input())

graph = [[] for _ in range(n + 1)]
for _ in range(n - 1):
    a, b = map(int, input().split())
    graph[a].append(b)
    graph[b].append(a)

parent = [0 for _ in range(n + 1)]
depth = [0 for _ in range(n + 1)]
visited = [0 for _ in range(n + 1)]

dfs(1, 0)

m = int(input())
for _ in range(m):
    a, b = map(int, input().split())
    print(lca(a, b))

# %% [markdown]
# 1761번 정점들의 거리 <span style="color:green">성공</span> - 2025.12.04

# %%
import sys
sys.setrecursionlimit(10**5)
# input = sys.stdin.readline

def dfs(curr, d):
    visited[curr] = 1
    for next, next_cost in graph[curr]:
        if not visited[next]:
            visited[next] = 1
            parent[next] = curr
            depth[next] = d + 1
            cost[next] = next_cost

            dfs(next, d + 1)

def lca(a, b):
    result = 0
    while depth[a] > depth[b]:
        result += cost[a]
        a = parent[a]
    while depth[a] < depth[b]:
        result += cost[b]
        b = parent[b]

    while a != b:
        result += cost[a]
        result += cost[b]

        a = parent[a]
        b = parent[b]

    return result

n = int(input())
graph = [[] for _ in range(n + 1)]
for _ in range(n - 1):
    a, b, c = map(int, input().split())
    graph[a].append([b, c])
    graph[b].append([a, c])

parent = [0 for _ in range(n + 1)]
depth = [0 for _ in range(n + 1)]
cost = [0 for _ in range(n + 1)]
visited = [0 for _ in range(n + 1)]

dfs(1, 0)

m = int(input())
for _ in range(m):
    a, b = map(int ,input().split())
    print(lca(a, b))

# %% [markdown]
# 11438번 LCA 2 <span style="color:red">실패</span> - 2025.12.05

# %%
import math
import sys
sys.setrecursionlimit(10**5)
# input = sys.stdin.readline

def dfs(curr, d):
    visited[curr] = 1
    for next in graph[curr]:
        if not visited[next]:
            visited[next] = 1

            parent[next][0] = curr
            depth[next] = d + 1
            dfs(next, d + 1)

def lca(a, b):
    if depth[a] > depth[b]:
        a, b = b, a

    diff = depth[b] - depth[a]
    for k in range(LOG + 1):
        if diff & (1 << k):
            b = parent[b][k]

    if a != b:
        for k in reversed(range(LOG + 1)):
            if parent[a][k] != parent[b][k]:
                a = parent[a][k]
                b = parent[b][k]
        return parent[a][0]
    else:
        return a

n = int(input())

LOG = int(math.log2(n))

graph = [[] for _ in range(n + 1)]
for _ in range(n - 1):
    a, b = map(int, input().split())
    graph[a].append(b)
    graph[b].append(a)

parent = [[0 for _ in range(LOG + 1)] for _ in range(n + 1)]
depth = [0 for _ in range(n + 1)]
visited = [0 for _ in range(n + 1)]

dfs(1, 0)

for k in range(1, LOG + 1):
    for i in range(1, n + 1):
        parent[i][k] = parent[parent[i][k - 1]][k - 1]

for i in range(1, n + 1):
    print(*parent[i])

m = int(input())
for _ in range(m):
    a, b = map(int, input().split())
    print(lca(a, b))
