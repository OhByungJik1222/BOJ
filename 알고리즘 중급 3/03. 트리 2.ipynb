# %% [markdown]
# 11437번 LCA <span style="color:green">성공</span> - 2025.12.03

# %%
# 두 노드의 깊이를 동일하게 맞춘 뒤, 부모를 타고 올라가며 같은 노드를 만날때까지 반복
import sys
from collections import deque
input = sys.stdin.readline

def bfs():
    q = deque()

    q.append(1)
    visited[1] = 1
    depth[1] = 0
    while q:
        curr = q.popleft()

        for next in graph[curr]:
            if not visited[next]:
                visited[next] = 1
                parent[next] = curr
                depth[next] = depth[curr] + 1
                q.append(next)

n = int(input())
graph = [[] for _ in range(n + 1)]
for _ in range(n - 1):
    a, b = map(int, input().split())
    graph[a].append(b)
    graph[b].append(a)

visited = [0 for _ in range(n + 1)]
parent = [0 for _ in range(n + 1)]
depth = [0 for _ in range(n + 1)]

bfs()

m = int(input())
for _ in range(m):
    a, b = map(int, input().split())

    if depth[a] != depth[b]:
        while depth[a] != depth[b]:
            if depth[a] < depth[b]:
                b = parent[b]
            
            elif depth[a] > depth[b]:
                a = parent[a]

    while a != b:
        a = parent[a]
        b = parent[b]
    print(a)

# %%
import sys
sys.setrecursionlimit(10**5)
input = sys.stdin.readline

def dfs(curr, d):
    visited[curr] = 1
    depth[curr] = d

    for next in graph[curr]:
        if not visited[next]:
            parent[next] = curr
            dfs(next, d + 1)

def lca(a, b):
    while depth[a] > depth[b]:
        a = parent[a]
    while depth[b] > depth[a]:
        b = parent[b]
    
    while a != b:
        a = parent[a]
        b = parent[b]
    return a

n = int(input())

graph = [[] for _ in range(n + 1)]
for _ in range(n - 1):
    a, b = map(int, input().split())
    graph[a].append(b)
    graph[b].append(a)

parent = [0 for _ in range(n + 1)]
depth = [0 for _ in range(n + 1)]
visited = [0 for _ in range(n + 1)]

dfs(1, 0)

m = int(input())
for _ in range(m):
    a, b = map(int, input().split())
    print(lca(a, b))

# %% [markdown]
# 1761번 정점들의 거리 <span style="color:green"></span> - 2025.12.04
